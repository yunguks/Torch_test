# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import time
import sys
import pytorch_model_summary
import numpy

print(f'torch : {torch.__version__}')
print(f'python : {sys.version}')
# Out:
# torch : 1.11.0
# python : 3.8.12 (default, Oct 12 2021, 13:49:34)
# [GCC 7.5.0]

# %%
# Train_data transform

train_transform = transforms.Compose(
    [   
        transforms.RandomHorizontalFlip(),
        transforms.RandomAffine(degrees=15),
        transforms.ToTensor(),
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    ]
)

test_transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    ]
)

batch_size = 128

# data download
train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform = train_transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size= batch_size,shuffle=True)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform = test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = batch_size, shuffle= True)

classes = ('plane','car','bird','cat','deer','dog','frog', 'horse', 'ship', 'truck')

print(f'train_set : {len(train_set)}')
print(f'test_set  : {len(test_set)}')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# train_set : 50000
# test_set  : 10000

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10):
        super(AlexNet,self).__init__()

        #self.features = features
        self.convlayer = nn.Sequential(
            # RGB 3 - > 64 / size(32,32)
            nn.Conv2d(in_channels=3, out_channels=96, kernel_size=5, padding=1, stride=1),
            # size(30,30)
            nn.ReLU(),
            nn.LocalResponseNorm(size=5, alpha=0.001, beta=0.75,k=2),
            nn.MaxPool2d(kernel_size=3,stride=2),
            
            # size (14,14)
            nn.Conv2d(in_channels=96,out_channels=256, kernel_size=5, padding=1, stride=1),
            # size (12,12)
            nn.ReLU(),
            nn.LocalResponseNorm(size=5, alpha=0.001, beta=0.75,k=2),
            nn.MaxPool2d(kernel_size=3, stride=2),
            # size (5,5)

            nn.Conv2d(in_channels=256, out_channels = 384, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=384,out_channels=384, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=384,out_channels=384, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),
            # size (2, 2)

        )

        self.fclayer =nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(384*2*2, 4096),
            #nn.BatchNorm1d(4096),
            nn.ReLU(True),
            nn.Dropout(0.5),
            nn.Linear(4096,4096),
            #nn.BatchNorm1d(4096),
            nn.ReLU(True),
            nn.Linear(4096,num_classes)
        )

    def forward(self, x):
        x = self.convlayer(x)
        #print(x.shape)
        x = torch.flatten(x,1)
        #print(x.shape)
        x = self.fclayer(x)
        return x

# %%
alex = AlexNet(num_classes=10)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')
#print(alex)
print(pytorch_model_summary.summary(alex,torch.zeros(128,3,32,32),show_input=True))

if device == 'cuda':
    alex = alex.to(device)
# summary
#
# Out:
# Using cuda device
# ------------------------------------------------------------------------------
#           Layer (type)            Input Shape         Param #     Tr. Param #
# ==============================================================================
#               Conv2d-1       [128, 3, 32, 32]           7,296           7,296
#                 ReLU-2      [128, 96, 30, 30]               0               0
#    LocalResponseNorm-3      [128, 96, 30, 30]               0               0
#            MaxPool2d-4      [128, 96, 30, 30]               0               0
#               Conv2d-5      [128, 96, 14, 14]         614,656         614,656
#                 ReLU-6     [128, 256, 12, 12]               0               0
#    LocalResponseNorm-7     [128, 256, 12, 12]               0               0
#            MaxPool2d-8     [128, 256, 12, 12]               0               0
#               Conv2d-9       [128, 256, 5, 5]         885,120         885,120
#                ReLU-10       [128, 384, 5, 5]               0               0
#              Conv2d-11       [128, 384, 5, 5]       1,327,488       1,327,488
#                ReLU-12       [128, 384, 5, 5]               0               0
#              Conv2d-13       [128, 384, 5, 5]       1,327,488       1,327,488
#                ReLU-14       [128, 384, 5, 5]               0               0
#           MaxPool2d-15       [128, 384, 5, 5]               0               0
#             Dropout-16            [128, 1536]               0               0
#              Linear-17            [128, 1536]       6,295,552       6,295,552
#                ReLU-18            [128, 4096]               0               0
#             Dropout-19            [128, 4096]               0               0
#              Linear-20            [128, 4096]      16,781,312      16,781,312
#                ReLU-21            [128, 4096]               0               0
#              Linear-22            [128, 4096]          40,970          40,970
# ==============================================================================
# Total params: 27,279,882
# Trainable params: 27,279,882
# Non-trainable params: 0
# ------------------------------------------------------------------------------

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(alex.parameters(), lr = 0.01, momentum=0.9)

# %%
loss_list = []
acc_list = []
test_acc_list = []
test_loss_list = []
epochs = 40
best_score = 0.0
for epoch in range(epochs):
    running_loss = 0.0
    running_acc = 0.0
    test_loss= 0.0
    start_time = time.time()
    total = 0
    t_total = 0
    correct =0 
    t_correct = 0
    for i, data in enumerate(train_loader):
        inputs, labels = data
        if device =='cuda':
            inputs = inputs.to(device)
            labels = labels.to(device)
            
        print(f'i : {i}, labels.shape :{labels.shape}')
        # gradients to zero
        optimizer.zero_grad()

        outputs = alex(inputs)
        print(f'output shape : {outputs.shape}')
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        _,predicted = torch.max(outputs,1)
        total += labels.size(0)
        running_acc += (predicted == labels).sum().item()
        running_loss += loss.item()

    # test data로 바로 확인
    with torch.no_grad():
        for t_data in test_loader:
            t_images, t_labels = t_data
            if device =='cuda':
                t_images= t_images.to(device)
                t_labels= t_labels.to(device)
            
            t_outputs = alex(t_images)
            t_loss = criterion(outputs, labels)

            _, t_predicted = torch.max(t_outputs,1)
            
            t_total += t_labels.size(0)
            t_correct += (t_predicted == t_labels).sum().item()

            test_loss += t_loss.item()
    if best_score < (t_correct/t_total):
        best_score = t_correct/t_total
        torch.save(alex,'./models/alex.pt')
    print(f'epoch : {epoch+1}, time :{time.time()-start_time:.2f}s')
    print(f'loss : {running_loss/len(train_loader):.3f}, acc: {running_acc/total:.2f}, ',end='')
    print(f'test_loss : {test_loss/len(test_loader):.3f}, test_acc : {t_correct/t_total:.2f}\n')
    loss_list.append(running_loss/len(train_loader))
    acc_list.append(running_acc/total)
    test_loss_list.append(test_loss/len(test_loader))
    test_acc_list.append(t_correct/t_total)

print(f'{"-"*20}\nFinish running\n\n')
# Out:
# i : 0, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 1, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 2, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 3, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 4, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 5, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 6, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 7, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 8, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 9, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 10, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 11, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 12, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 13, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 14, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 15, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 16, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 17, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 18, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 19, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 20, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 21, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 22, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 23, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 24, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 25, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 26, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 27, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 28, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 29, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 30, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 31, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 32, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 33, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 34, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 35, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 36, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 37, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 38, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 39, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 40, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 41, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 42, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 43, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 44, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 45, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 46, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 47, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 48, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 49, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 50, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 51, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 52, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 53, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 54, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 55, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 56, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 57, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 58, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 59, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 60, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 61, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 62, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 63, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 64, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 65, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 66, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 67, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 68, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 69, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 70, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 71, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 72, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 73, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 74, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 75, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 76, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 77, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 78, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 79, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 80, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 81, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 82, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 83, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 84, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 85, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 86, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 87, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 88, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 89, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 90, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 91, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 92, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 93, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 94, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 95, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 96, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 97, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 98, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 99, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 100, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 101, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 102, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 103, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 104, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 105, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 106, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 107, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 108, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 109, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 110, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 111, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 112, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 113, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 114, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 115, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 116, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 117, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 118, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 119, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 120, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 121, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 122, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 123, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 124, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 125, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 126, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 127, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 128, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 129, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 130, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 131, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 132, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 133, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 134, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 135, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 136, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 137, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 138, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 139, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 140, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 141, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 142, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 143, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 144, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 145, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 146, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 147, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 148, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 149, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 150, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 151, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 152, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 153, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 154, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 155, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 156, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 157, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 158, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# i : 159, labels.shape :torch.Size([128])
# output shape : torch.Size([128, 10])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_275844/2564136896.py in <module>
#      14     correct =0
#      15     t_correct = 0
# ---> 16     for i, data in enumerate(train_loader):
#      17         inputs, labels = data
#      18         if device =='cuda':
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /opt/conda/lib/python3.8/site-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#     113         # doing this so that it is consistent with all other datasets
#     114         # to return a PIL Image
# --> 115         img = Image.fromarray(img)
#     116
#     117         if self.transform is not None:
#
# /opt/conda/lib/python3.8/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2832             obj = obj.tostring()
#    2833
# -> 2834     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2835
#    2836
#
# /opt/conda/lib/python3.8/site-packages/PIL/Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2759             return im
#    2760
# -> 2761     return frombytes(mode, size, data, decoder_name, args)
#    2762
#    2763
#
# /opt/conda/lib/python3.8/site-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2705
#    2706     im = new(mode, size)
# -> 2707     im.frombytes(data, decoder_name, args)
#    2708     return im
#    2709
#
# /opt/conda/lib/python3.8/site-packages/PIL/Image.py in frombytes(self, data, decoder_name, *args)
#     781         s = d.decode(data)
#     782
# --> 783         if s[0] >= 0:
#     784             raise ValueError("not enough image data")
#     785         if s[1] != 0:
#
# KeyboardInterrupt:

# %%
best=torch.load('./models/alex.pt')
correct = 0
total = 0
class_correct = {classname : 0 for classname in classes}
class_total = {classname : 0 for classname in classes}
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        if device =='cuda':
            images= images.to(device)
            labels= labels.to(device)
        
        outputs = best(images)
        _, predicted = torch.max(outputs,1)
        
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        for label, predict in zip(labels,predicted):
            if label == predict:
                class_correct[classes[label]] +=1
            class_total[classes[label]] +=1

print(f'Total Accuracy : {100* correct /total:.1f}%\n')

for classname, number in class_correct.items():
    print(f'Accuray of {classname} : {100*number/class_total[classname]:.1f}%')
# Out:
# Total Accuracy : 83.3%
#
# Accuray of plane : 85.1%
# Accuray of car : 89.9%
# Accuray of bird : 78.0%
# Accuray of cat : 65.0%
# Accuray of deer : 86.9%
# Accuray of dog : 72.1%
# Accuray of frog : 88.6%
# Accuray of horse : 85.3%
# Accuray of ship : 89.9%
# Accuray of truck : 92.2%

# %%
# 확인 하기 , input과 output의 데이터
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        if device =='cuda':
            images= images.to(device)
            labels= labels.to(device)
        
        outputs = alex(images)
        _, predicted = torch.max(outputs,1)
        print(f'predicted : {predicted}, size : {predicted.shape}')
        print(f'images : {images.shape}')
        print(f'labels : {labels.shape}')
        print(f'labels.size(0) : {labels.size(0)}')
        break
# Out:
# predicted : tensor([9, 6, 0, 5, 1, 6, 2, 3, 7, 4, 3, 4, 5, 9, 4, 9, 7, 9, 2, 7, 5, 0, 7, 7,
#         1, 2, 5, 0, 6, 1, 3, 5, 1, 3, 7, 4, 7, 8, 0, 1, 4, 6, 6, 7, 2, 8, 0, 9,
#         8, 5, 8, 4, 2, 1, 9, 9, 5, 5, 8, 5, 1, 9, 5, 3, 0, 8, 7, 8, 3, 3, 6, 0,
#         5, 1, 7, 1, 6, 0, 4, 8, 8, 5, 3, 4, 3, 2, 2, 7, 6, 2, 1, 3, 9, 1, 8, 6,
#         9, 3, 8, 3, 4, 9, 7, 7, 1, 8, 4, 2, 8, 2, 3, 6, 7, 5, 0, 4, 1, 3, 7, 8,
#         4, 2, 1, 8, 9, 4, 3, 1], device='cuda:0'), size : torch.Size([128])
# images : torch.Size([128, 3, 32, 32])
# labels : torch.Size([128])
# labels.size(0) : 128

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.plot(range(1,epochs+1),loss_list,label='train loss')
plt.plot(range(1,epochs+1),test_loss_list,label='test loss')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(range(1,epochs+1),acc_list,label='train acc')
plt.plot(range(1,epochs+1),test_acc_list,label='test acc')
plt.xlabel('epoch')
plt.ylabel('Acc')
plt.legend()

plt.show()
